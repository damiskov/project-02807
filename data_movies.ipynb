# %%
import os
import re
import csv
import time
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
from pathlib import Path

# %%
BASE = "https://www.midiworld.com"
NUM_PAGES = 2
DOWNLOAD_DIR = "midi_downloads"
CSV_FILE = "movie_themes.csv"
OMDB_KEY = "YOUR_KEY_HERE"        # ← free at omdbapi.com
os.makedirs(DOWNLOAD_DIR, exist_ok=True)                     # seconds between downloads (be nice)

# %% [markdown]
# Generate the pages to scrape data from

# %%
PAGES = [i for i in range(1, NUM_PAGES+1)]
print(PAGES)
# Out:
# [1, 2]

# %% [markdown]
# Request the year of release for a title, using the OMDb API (later)

# %%
year_cache = {}
def get_year(title):
    if title in year_cache: return year_cache[title]
    clean = re.sub(r"\s*\(.*?\)$", "", title.split("-")[0]).strip()
    url = "http://www.omdbapi.com/"
    try:
        r = requests.get(url, params={"apikey": OMDB_KEY, "t": clean}, timeout=5).json()
        y = r.get("Year", "Unknown").split("–")[0]
    except:
        y = "Unknown"
    year_cache[title] = y
    return y

# %% [markdown]
# Download all .midi files for each movie inside each page

# %%
rows = []

for page in PAGES:
    url = f"https://www.midiworld.com/search/{page}/?q=movie%20themes"
    print(f"\nScraping page {page}")
    soup = BeautifulSoup(requests.get(url).text, "html.parser")

    for li in soup.find_all("li"):
        text = li.get_text()
        if "(Movie Themes)" not in text:
            continue

        # Extract title
        match = re.search(r"^([\s\S]*?)\s*\(Movie Themes\)", str(text))
    
        if not match:
            continue

        title = match.group(1).strip()
        title = re.sub(r"\s*-?\s*$", "", title)
        print(f"Title: {title}")

        # Get download links inside <li> tags
        links = li.find_all("a", href=True, string="download")
        midis = []
        print(links)

        for a in links:
            dl_url = urljoin("https://www.midiworld.com", a["href"])
            # The real .mid is in redirect → follow it
            try:
                real_url = requests.head(dl_url, allow_redirects=True).url
                # if not real_url.endswith(".mid"):
                #     continue
            except:
                continue

            clean_title = title.strip()
            clean_title = re.sub(r'\s+', '_', clean_title)   # spaces → single _
            clean_title = re.sub(r'[^\w\-]', '', clean_title)
            filename   = f"{clean_title}.midi"

            # fname = f"{title} - {os.path.basename(real_url)}"
            # fpath = os.path.join(DOWNLOAD_DIR, re.sub(r'[<>:"/\\|?*]', '_', fname))
            # fpath = os.path.join(DOWNLOAD_DIR, filename)
            fpath = Path(DOWNLOAD_DIR) / filename

            if not os.path.exists(fpath):
                print(f"  ↓ {filename}")
                r = requests.get(real_url, allow_redirects=True)
                fpath.write_bytes(r.content)
                time.sleep(0.4)

                
                print("clean: ", clean_title)

            else:
                print(f"  Already have {filename}")

            midis.append(filename)

        # year = get_year(title)
        year = "-"
        rows.append([title, year, "; ".join(midis) if midis else ""])
# Out:
# Scraping page 1...
# → 1492 Conquest of Paradise
# [<a href="https://www.midiworld.com/download/3777" target="_blank">download</a>]
#   ↓ 1492_Conquest_of_Paradise.midi
# clean:  1492_Conquest_of_Paradise
# → 1941
# [<a href="https://www.midiworld.com/download/3778" target="_blank">download</a>]
#   ↓ 1941.midi
# clean:  1941
# → 2001 - Also Sprach Zarathustra Richard Strauss
# [<a href="https://www.midiworld.com/download/3779" target="_blank">download</a>]
#   ↓ 2001_-_Also_Sprach_Zarathustra_Richard_Strauss.midi
# clean:  2001_-_Also_Sprach_Zarathustra_Richard_Strauss
# → 20th Century Fox
# [<a href="https://www.midiworld.com/download/3780" target="_blank">download</a>]
#   ↓ 20th_Century_Fox.midi
# clean:  20th_Century_Fox
# → 54 - If You Could Read My Mind by Gordon Lightfoot
# [<a href="https://www.midiworld.com/download/3781" target="_blank">download</a>]
#   ↓ 54_-_If_You_Could_Read_My_Mind_by_Gordon_Lightfoot.midi
# clean:  54_-_If_You_Could_Read_My_Mind_by_Gordon_Lightfoot
# → 633 Squadron
# [<a href="https://www.midiworld.com/download/3782" target="_blank">download</a>]
#   ↓ 633_Squadron.midi
# clean:  633_Squadron
# → The Accidental Tourist
# [<a href="https://www.midiworld.com/download/3783" target="_blank">download</a>]
#   ↓ The_Accidental_Tourist.midi
# clean:  The_Accidental_Tourist
# → Ace Ventura Pet Detective
# [<a href="https://www.midiworld.com/download/3784" target="_blank">download</a>]
#   ↓ Ace_Ventura_Pet_Detective.midi
# clean:  Ace_Ventura_Pet_Detective
# → Addams Family
# [<a href="https://www.midiworld.com/download/3785" target="_blank">download</a>]
#   ↓ Addams_Family.midi
# clean:  Addams_Family
# → Addicted To Love
# [<a href="https://www.midiworld.com/download/3786" target="_blank">download</a>]
#   ↓ Addicted_To_Love.midi
# clean:  Addicted_To_Love
# → Advance To The Rear
# [<a href="https://www.midiworld.com/download/3787" target="_blank">download</a>]
#   ↓ Advance_To_The_Rear.midi
# clean:  Advance_To_The_Rear
# → Against All Odds
# [<a href="https://www.midiworld.com/download/3788" target="_blank">download</a>]
#   ↓ Against_All_Odds.midi
# clean:  Against_All_Odds
# → Air Force One
# [<a href="https://www.midiworld.com/download/3789" target="_blank">download</a>]
#   ↓ Air_Force_One.midi
# clean:  Air_Force_One
# → Armageddon
# [<a href="https://www.midiworld.com/download/3790" target="_blank">download</a>]
#   ↓ Armageddon.midi
# clean:  Armageddon
# → Austin Powers
# [<a href="https://www.midiworld.com/download/3791" target="_blank">download</a>]
#   ↓ Austin_Powers.midi
# clean:  Austin_Powers
# → Back to the Future
# [<a href="https://www.midiworld.com/download/3792" target="_blank">download</a>]
#   ↓ Back_to_the_Future.midi
# clean:  Back_to_the_Future
# → Batman
# [<a href="https://www.midiworld.com/download/3793" target="_blank">download</a>]
#   ↓ Batman.midi
# clean:  Batman
# → Beetlejuice - by Danny Elfman
# [<a href="https://www.midiworld.com/download/3794" target="_blank">download</a>]
#   ↓ Beetlejuice_-_by_Danny_Elfman.midi
# clean:  Beetlejuice_-_by_Danny_Elfman
# → Beverly Hills Cop - Axel's Theme by Harold Faltermeyer
# [<a href="https://www.midiworld.com/download/3795" target="_blank">download</a>]
# [<a href="https://www.midiworld.com/download/3810" target="_blank">download</a>]
#   ↓ Escape_from_LA.midi
# clean:  Escape_from_LA
# → Escape from New York
# [<a href="https://www.midiworld.com/download/3811" target="_blank">download</a>]
#   ↓ Escape_from_New_York.midi
# clean:  Escape_from_New_York
# → Evita
# [<a href="https://www.midiworld.com/download/3812" target="_blank">download</a>]
#   ↓ Evita.midi
# clean:  Evita
# → Fame
# [<a href="https://www.midiworld.com/download/3813" target="_blank">download</a>]
#   ↓ Fame.midi
# clean:  Fame
# → Flashdance
# [<a href="https://www.midiworld.com/download/3814" target="_blank">download</a>]
#   ↓ Flashdance.midi
# clean:  Flashdance
# → Footloose - by Kenny Loggins
# [<a href="https://www.midiworld.com/download/3815" target="_blank">download</a>]
#   ↓ Footloose_-_by_Kenny_Loggins.midi
# clean:  Footloose_-_by_Kenny_Loggins
# → Forrest Gump
# [<a href="https://www.midiworld.com/download/3816" target="_blank">download</a>]
#   ↓ Forrest_Gump.midi
# clean:  Forrest_Gump
# → George Of The Jungle
# [<a href="https://www.midiworld.com/download/3817" target="_blank">download</a>]
#   ↓ George_Of_The_Jungle.midi
# clean:  George_Of_The_Jungle
# → Ghostbusters
# [<a href="https://www.midiworld.com/download/3818" target="_blank">download</a>]
#   ↓ Ghostbusters.midi
# clean:  Ghostbusters
# → Goldfinger
# [<a href="https://www.midiworld.com/download/3819" target="_blank">download</a>]
#   ↓ Goldfinger.midi
# clean:  Goldfinger
# → The Graduate - Mrs. Robinson by Simon & Garfunkel
# [<a href="https://www.midiworld.com/download/3820" target="_blank">download</a>]
#   ↓ The_Graduate_-_Mrs_Robinson_by_Simon__Garfunkel.midi
# clean:  The_Graduate_-_Mrs_Robinson_by_Simon__Garfunkel
# → Grease - Summer Love
# [<a href="https://www.midiworld.com/download/3821" target="_blank">download</a>]
#   ↓ Grease_-_Summer_Love.midi
# clean:  Grease_-_Summer_Love
# → Grease - You're The One That I Want
# [<a href="https://www.midiworld.com/download/3822" target="_blank">download</a>]
#   ↓ Grease_-_Youre_The_One_That_I_Want.midi
# clean:  Grease_-_Youre_The_One_That_I_Want
# → The Good, the Bad and the Ugly
# [<a href="https://www.midiworld.com/download/3823" target="_blank">download</a>]
#   ↓ The_Good_the_Bad_and_the_Ugly.midi
# clean:  The_Good_the_Bad_and_the_Ugly
# → Hair - Aquarius
# [<a href="https://www.midiworld.com/download/3824" target="_blank">download</a>]
#   ↓ Hair_-_Aquarius.midi
# clean:  Hair_-_Aquarius
# → Hatari - Baby Elephant Walk by Henry Mancini
# [<a href="https://www.midiworld.com/download/3825" target="_blank">download</a>]
#   ↓ Hatari_-_Baby_Elephant_Walk_by_Henry_Mancini.midi
# clean:  Hatari_-_Baby_Elephant_Walk_by_Henry_Mancini
# → James Bond
# [<a href="https://www.midiworld.com/download/3826" target="_blank">download</a>]
#   ↓ James_Bond.midi
# clean:  James_Bond
# → Jaws
# [<a href="https://www.midiworld.com/download/3827" target="_blank">download</a>]
#   ↓ Jaws.midi
# clean:  Jaws
# → Jurassic Park
# [<a href="https://www.midiworld.com/download/3828" target="_blank">download</a>]
#   ↓ Jurassic_Park.midi
# clean:  Jurassic_Park
# → King Kong
# [<a href="https://www.midiworld.com/download/3829" target="_blank">download</a>]
#   ↓ King_Kong.midi
# clean:  King_Kong
# → Legends Of The Fall
# [<a href="https://www.midiworld.com/download/3830" target="_blank">download</a>]
#   ↓ Legends_Of_The_Fall.midi
# clean:  Legends_Of_The_Fall
# → The Matrix
# [<a href="https://www.midiworld.com/download/3831" target="_blank">download</a>]
#   ↓ The_Matrix.midi
# clean:  The_Matrix
# → Midnight Cowboy
# [<a href="https://www.midiworld.com/download/3832" target="_blank">download</a>]
#   ↓ Midnight_Cowboy.midi
# clean:  Midnight_Cowboy
# → Mission Impossible - by Lalo Schiffrin
# [<a href="https://www.midiworld.com/download/3833" target="_blank">download</a>]
#   ↓ Mission_Impossible_-_by_Lalo_Schiffrin.midi
# clean:  Mission_Impossible_-_by_Lalo_Schiffrin
# → Mortal Kombat
# [<a href="https://www.midiworld.com/download/3834" target="_blank">download</a>]
#   ↓ Mortal_Kombat.midi
# clean:  Mortal_Kombat
# → My Girl
# [<a href="https://www.midiworld.com/download/3835" target="_blank">download</a>]
#   ↓ My_Girl.midi
# clean:  My_Girl
# → The Naked Gun
# [<a href="https://www.midiworld.com/download/3836" target="_blank">download</a>]
#   ↓ The_Naked_Gun.midi
# clean:  The_Naked_Gun

# %%
print(rows)
# Out:
# [['1492 Conquest of Paradise', '-', '1492_Conquest_of_Paradise.midi'], ['1941', '-', '1941.midi'], ['2001 - Also Sprach Zarathustra Richard Strauss', '-', '2001_-_Also_Sprach_Zarathustra_Richard_Strauss.midi'], ['20th Century Fox', '-', '20th_Century_Fox.midi'], ['54 - If You Could Read My Mind by Gordon Lightfoot', '-', '54_-_If_You_Could_Read_My_Mind_by_Gordon_Lightfoot.midi'], ['633 Squadron', '-', '633_Squadron.midi'], ['The Accidental Tourist', '-', 'The_Accidental_Tourist.midi'], ['Ace Ventura Pet Detective', '-', 'Ace_Ventura_Pet_Detective.midi'], ['Addams Family', '-', 'Addams_Family.midi'], ['Addicted To Love', '-', 'Addicted_To_Love.midi'], ['Advance To The Rear', '-', 'Advance_To_The_Rear.midi'], ['Against All Odds', '-', 'Against_All_Odds.midi'], ['Air Force One', '-', 'Air_Force_One.midi'], ['Armageddon', '-', 'Armageddon.midi'], ['Austin Powers', '-', 'Austin_Powers.midi'], ['Back to the Future', '-', 'Back_to_the_Future.midi'], ['Batman', '-', 'Batman.midi'], ['Beetlejuice - by Danny Elfman', '-', 'Beetlejuice_-_by_Danny_Elfman.midi'], ["Beverly Hills Cop - Axel's Theme by Harold Faltermeyer", '-', 'Beverly_Hills_Cop_-_Axels_Theme_by_Harold_Faltermeyer.midi'],