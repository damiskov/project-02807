# %% [markdown]
# # Graph-Enhanced Clustering of Classical Music Using Note-Sequence and Structural Similarity
# ## 02408 - Computational Tools for Data Science
# ### Group 44
# - David Miles-Skov
# - Javier Yanes Pulido
# - Irene González Luján
# - Patrick Jensen Martins
# - Karl Find Hansen

# %% [markdown]
# > NOTE: WIP!
#
# This notebook contains an overview of our implementations and findings throughout our project.
